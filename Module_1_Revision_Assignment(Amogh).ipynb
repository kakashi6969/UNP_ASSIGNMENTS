# %% [markdown]
# # Amogh Jagini

# %% [markdown]
# ### About the dataset
# Housing dataset contains the information of the properties sold in the city of "Nashville" over a sapn of 40 years. It contains all the necessary information like the area of the property, amount it was sold for, number of rooms that the property has etc. Our aim is to find some interesting insights from the data.
#
# ### Loading data
# 1. Import the "housing" data using appropriate functions.
#
#
# ### Cleaning data
# 1. Replace the missing values with appropriate approximations
# 2. Rename the columns to better suited names
# 3. Extract the month and year from the sale date.
# 4. Extract the pin number from the property address
#
#
# ### EDA
# Use appropriate plots and functions to answer the following questions.
#
# 1. How has the price of properties changed over the years
# 2. Does a specific month or span of months have the highest property prices?
# 3. For what purpose were the properties generally purchased?
# 4. What is the average age of the properties?
# 5. Have the age of houses affected the price?
# 6. Have the number of rooms in the house affected the price?
# 7. Does the size of the property (no. of acres) have any influence in its price?
# 8. Are houses located in specific pin numbers expensive over the others?
# 9. How have house prices changed in the 21st centuary as supposed to 20th centuary.

# %% [markdown]
# # New Section

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set(color_codes=True)

# %% [markdown]
# LOADING DATA

# %%
data = pd.read_excel('Housing.xlsx')
data.head()
# Out:
#    UniqueID         LandUse                     PropertyAddress   SaleDate  \
# 0       2045  SINGLE FAMILY  1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09
# 1      16918  SINGLE FAMILY  1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10
# 2      54582  SINGLE FAMILY  1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26
# 3      43070  SINGLE FAMILY  1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29
# 4      22714  SINGLE FAMILY  1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10
#
#    SalePrice  Acre  LandValue  BuildingValue  TotalValue  YearBuilt  Bedrooms  \
# 0     240000   2.3    50000.0       168200.0    235700.0     1986.0       3.0
# 1     366000   3.5    50000.0       264100.0    319000.0     1998.0       3.0
# 2     435000   2.9    50000.0       216200.0    298000.0     1987.0       4.0
# 3     255000   2.6    50000.0       147300.0    197300.0     1985.0       3.0
# 4     278000   2.0    50000.0       152300.0    202300.0     1984.0       4.0
#
#    FullBath  HalfBath
# 0       3.0       0.0
# 1       3.0       2.0
# 2       3.0       0.0
# 3       3.0       0.0
# 4       3.0       0.0

# %% [markdown]
# **CLEANING DATA**

# %%
data.isnull().sum()
# Out:
# UniqueID               0
# LandUse                0
# PropertyAddress       29
# SaleDate               0
# SalePrice              0
# Acre               30462
# LandValue          30462
# BuildingValue      30462
# TotalValue         30462
# YearBuilt          32314
# Bedrooms           32320
# FullBath           32202
# HalfBath           32333
# dtype: int64

# %% [markdown]
# 1. Replace the missing values with appropriate approximations

# %%
data['Acre']=data["Acre"].fillna(np.mean(data["Acre"]))
data['LandValue']=data["LandValue"].fillna(np.mean(data["LandValue"]))
data['BuildingValue']=data["BuildingValue"].fillna(np.mean(data["BuildingValue"]))
data['TotalValue']=data["TotalValue"].fillna(np.mean(data["TotalValue"]))
data['YearBuilt']=data["YearBuilt"].fillna(np.mean(data["YearBuilt"]))
data['Bedrooms']=data["Bedrooms"].fillna(np.mean(data["Bedrooms"]))
data['FullBath']=data["FullBath"].fillna(np.mean(data["FullBath"]))
data['HalfBath']=data["HalfBath"].fillna(np.mean(data["HalfBath"]))
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBath  HalfBath
# 0      3.000000  0.000000
# 1      3.000000  2.000000
# 2      3.000000  0.000000
# 3      3.000000  0.000000
# 4      3.000000  0.000000
# ...         ...       ...
# 56472  1.886014  0.283921
# 56473  1.886014  0.283921
# 56474  1.886014  0.283921
# 56475  1.886014  0.283921
# 56476  1.886014  0.283921
#
# [56477 rows x 13 columns]

# %% [markdown]
# **2. Rename the columns to better suited names**

# %%
data.columns
# Out:
# Index(['UniqueID ', 'LandUse', 'PropertyAddress', 'SaleDate', 'SalePrice',
#        'Acre', 'LandValue', 'BuildingValue', 'TotalValue', 'YearBuilt',
#        'Bedrooms', 'FullBath', 'HalfBath'],
#       dtype='object')

# %%
data.rename(columns={"FullBath":"FullBathroom"},inplace=True)
data.rename(columns={"HalfBath":"HalfBathroom"},inplace=True)

# %% [markdown]
# **3. Extract the month and year from the sale date.**

# %%
data['Year']=pd.DatetimeIndex(data['SaleDate']).year
data['Month']=pd.DatetimeIndex(data['SaleDate']).month
data['Day']=pd.DatetimeIndex(data['SaleDate']).day
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day
# 0          3.000000      0.000000  2013      4    9
# 1          3.000000      2.000000  2014      6   10
# 2          3.000000      0.000000  2016      9   26
# 3          3.000000      0.000000  2016      1   29
# 4          3.000000      0.000000  2014     10   10
# ...             ...           ...   ...    ...  ...
# 56472      1.886014      0.283921  2015      5   27
# 56473      1.886014      0.283921  2015      3    2
# 56474      1.886014      0.283921  2016      8   16
# 56475      1.886014      0.283921  2016      9    7
# 56476      1.886014      0.283921  2016      9    7
#
# [56477 rows x 16 columns]

# %% [markdown]
# **4. Extract the pin number from the property address**

# %%
data.dtypes
# Out:
# UniqueID                    int64
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# Acre                      float64
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBathroom              float64
# HalfBathroom              float64
# Year                        int64
# Month                       int64
# Day                         int64
# dtype: object

# %%
Address = data['PropertyAddress'].astype(str)
Address
# Out:
# 0         1808  FOX CHASE DR, GOODLETTSVILLE
# 1         1832  FOX CHASE DR, GOODLETTSVILLE
# 2         1864 FOX CHASE  DR, GOODLETTSVILLE
# 3         1853  FOX CHASE DR, GOODLETTSVILLE
# 4         1829  FOX CHASE DR, GOODLETTSVILLE
#                         ...
# 56472    1435  WINDING CREEK DR, NOLENSVILLE
# 56473    1423  WINDING CREEK DR, NOLENSVILLE
# 56474      1804 GRACE POINT  LN, NOLENSVILLE
# 56475     1709 PARK TERRACE  LN, NOLENSVILLE
# 56476     1713 PARK TERRACE  LN, NOLENSVILLE
# Name: PropertyAddress, Length: 56477, dtype: object

# %%
data['Pin'] = Address.str[:4]
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day   Pin
# 0          3.000000      0.000000  2013      4    9  1808
# 1          3.000000      2.000000  2014      6   10  1832
# 2          3.000000      0.000000  2016      9   26  1864
# 3          3.000000      0.000000  2016      1   29  1853
# 4          3.000000      0.000000  2014     10   10  1829
# ...             ...           ...   ...    ...  ...   ...
# 56472      1.886014      0.283921  2015      5   27  1435
# 56473      1.886014      0.283921  2015      3    2  1423
# 56474      1.886014      0.283921  2016      8   16  1804
# 56475      1.886014      0.283921  2016      9    7  1709
# 56476      1.886014      0.283921  2016      9    7  1713
#
# [56477 rows x 17 columns]

# %% [markdown]
# **EDA**

# %% [markdown]
# 1. How has the price of properties changed over the years

# %%
sns.barplot(y='SalePrice',x='Year',data=data)

# %%
#We observe that the price of properties saw a steady increase from 2013 up until 2015 which is followed by a continious decline till 2019.

# %% [markdown]
# 2. Does a specific month or span of months have the highest property prices?

# %%
c = data.groupby('Month')['SalePrice'].median()

# %%
c
# Out:
# Month
# 1     199900.0
# 2     190000.0
# 3     196000.0
# 4     200000.0
# 5     220750.0
# 6     222505.0
# 7     203500.0
# 8     208000.0
# 9     210000.0
# 10    200000.0
# 11    200000.0
# 12    200000.0
# Name: SalePrice, dtype: float64

# %%
sns.barplot(y=c.values,x=c.index)

# %%
#Months 5 and 6 have the highest property prices

# %% [markdown]
# 3. For what purpose were the properties generally purchased?

# %%
d = data.groupby('LandUse')['SalePrice'].count()
d
# Out:
# LandUse
# APARTMENT: LOW RISE (BUILT SINCE 1960)            2
# CHURCH                                           34
# CLUB/UNION HALL/LODGE                             1
# CONDO                                           247
# CONDOMINIUM OFC  OR OTHER COM CONDO              35
# CONVENIENCE MARKET WITHOUT GAS                    1
# DAY CARE CENTER                                   2
# DORMITORY/BOARDING HOUSE                         19
# DUPLEX                                         1373
# FOREST                                           10
# GREENBELT                                        10
# GREENBELT/RES_x000D_\nGRRENBELT/RES               3
# LIGHT MANUFACTURING                               1
# METRO OTHER THAN OFC, SCHOOL,HOSP, OR PARK        1
# MOBILE HOME                                      20
# MORTUARY/CEMETERY                                 1
# NIGHTCLUB/LOUNGE                                  1
# NON-PROFIT CHARITABLE SERVICE                     2
# OFFICE BLDG (ONE OR TWO STORIES)                  2
# ONE STORY GENERAL RETAIL STORE                    1
# PARKING LOT                                      11
# PARSONAGE                                         6
# QUADPLEX                                         39
# RESIDENTIAL COMBO/MISC                           95
# RESIDENTIAL CONDO                             14080
# RESTURANT/CAFETERIA                               2
# SINGLE FAMILY                                 34197
# SMALL SERVICE SHOP                                1
# SPLIT CLASS                                      17
# STRIP SHOPPING CENTER                             1
# TERMINAL/DISTRIBUTION WAREHOUSE                   2
# TRIPLEX                                          92
# VACANT COMMERCIAL LAND                           17
# VACANT RES LAND                                1549
# VACANT RESIDENTIAL LAND                        3547
# VACANT RESIENTIAL LAND                            3
# VACANT RURAL LAND                                 2
# VACANT ZONED MULTI FAMILY                         2
# ZERO LOT LINE                                  1048
# Name: SalePrice, dtype: int64

# %%
plt.pie(d,labels=d.index,autopct="%.2f%%")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
#It is observed that majority of properties are generally used for 'single family' and 'resendential condo'

# %% [markdown]
# 4. What is the average age of the properties?

# %%
from datetime import datetime, date

# %%
now = datetime.now().year
now = int(now)
now
# Out:
# 2022

# %%
data['Age'] = (now - data['YearBuilt'])

# %%
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day   Pin        Age     Rooms
# 0          3.000000      0.000000  2013      4    9  1808  36.000000  6.000000
# 1          3.000000      2.000000  2014      6   10  1832  24.000000  8.000000
# 2          3.000000      0.000000  2016      9   26  1864  35.000000  7.000000
# 3          3.000000      0.000000  2016      1   29  1853  37.000000  6.000000
# 4          3.000000      0.000000  2014     10   10  1829  38.000000  7.000000
# ...             ...           ...   ...    ...  ...   ...        ...       ...
# 56472      1.886014      0.283921  2015      5   27  1435  58.255101  5.259848
# 56473      1.886014      0.283921  2015      3    2  1423  58.255101  5.259848
# 56474      1.886014      0.283921  2016      8   16  1804  58.255101  5.259848
# 56475      1.886014      0.283921  2016      9    7  1709  58.255101  5.259848
# 56476      1.886014      0.283921  2016      9    7  1713  58.255101  5.259848
#
# [56477 rows x 19 columns]

# %%
Avg_age = data['Age'].median()
Avg_age
# Out:
# 58.2551007739105

# %%
#Average age of the properties is 58.26 years as of 2022

# %% [markdown]
# 5. Have the age of houses affected the price?

# %%
data.dtypes
# Out:
# UniqueID                    int64
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# Acre                      float64
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBathroom              float64
# HalfBathroom              float64
# Year                        int64
# Month                       int64
# Day                         int64
# Pin                        object
# Age                       float64
# Rooms                     float64
# dtype: object

# %%
Age = data['Age'].astype(int)
Age
# Out:
# 0        36
# 1        24
# 2        35
# 3        37
# 4        38
#          ..
# 56472    58
# 56473    58
# 56474    58
# 56475    58
# 56476    58
# Name: Age, Length: 56477, dtype: int64

# %%
np.corrcoef(Age,data.SalePrice)
# Out:
# array([[ 1.       , -0.0085471],
#        [-0.0085471,  1.       ]])

# %%
sns.scatterplot(x='Age',y='SalePrice',data=data)

# %%
#The correlation coefficient is slightly negative but looking at the scatterplot we can conclude that there is no real affect of age on the price of the property

# %% [markdown]
# 6. Have the number of rooms in the house affected the price?

# %%
data["Rooms"]=data['Bedrooms']+data['FullBathroom']+data['HalfBathroom']
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day   Pin        Age  \
# 0          3.000000      0.000000  2013      4    9  1808  36.000000
# 1          3.000000      2.000000  2014      6   10  1832  24.000000
# 2          3.000000      0.000000  2016      9   26  1864  35.000000
# 3          3.000000      0.000000  2016      1   29  1853  37.000000
# 4          3.000000      0.000000  2014     10   10  1829  38.000000
# ...             ...           ...   ...    ...  ...   ...        ...
# 56472      1.886014      0.283921  2015      5   27  1435  58.255101
# 56473      1.886014      0.283921  2015      3    2  1423  58.255101
# 56474      1.886014      0.283921  2016      8   16  1804  58.255101
# 56475      1.886014      0.283921  2016      9    7  1709  58.255101
# 56476      1.886014      0.283921  2016      9    7  1713  58.255101
#
#           Rooms  TotalRooms
# 0      6.000000    6.000000
# 1      8.000000    8.000000
# 2      7.000000    7.000000
# 3      6.000000    6.000000
# 4      7.000000    7.000000
# ...         ...         ...
# 56472  5.259848    5.259848
# 56473  5.259848    5.259848
# 56474  5.259848    5.259848
# 56475  5.259848    5.259848
# 56476  5.259848    5.259848
#
# [56477 rows x 20 columns]

# %%
np.corrcoef(data.Rooms,data.SalePrice)
# Out:
# array([[1.        , 0.11454137],
#        [0.11454137, 1.        ]])

# %%
sns.regplot(x='Rooms',y='SalePrice',data=data)

# %%
#We observe that the number of rooms has a slightly postive but negligible correlation with the SalePrice

# %% [markdown]
# 7. Does the size of the property (no. of acres) have any influence in its price?

# %%
data
# Out:
#        UniqueID                   LandUse  \
# 0           2045            SINGLE FAMILY
# 1          16918            SINGLE FAMILY
# 2          54582            SINGLE FAMILY
# 3          43070            SINGLE FAMILY
# 4          22714            SINGLE FAMILY
# ...          ...                      ...
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                            PropertyAddress   SaleDate  SalePrice      Acre  \
# 0       1808  FOX CHASE DR, GOODLETTSVILLE 2013-04-09     240000  2.300000
# 1       1832  FOX CHASE DR, GOODLETTSVILLE 2014-06-10     366000  3.500000
# 2       1864 FOX CHASE  DR, GOODLETTSVILLE 2016-09-26     435000  2.900000
# 3       1853  FOX CHASE DR, GOODLETTSVILLE 2016-01-29     255000  2.600000
# 4       1829  FOX CHASE DR, GOODLETTSVILLE 2014-10-10     278000  2.000000
# ...                                    ...        ...        ...       ...
# 56472  1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473  1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474    1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475   1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476   1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 0      50000.000000  168200.000000  235700.000000  1986.000000  3.000000
# 1      50000.000000  264100.000000  319000.000000  1998.000000  3.000000
# 2      50000.000000  216200.000000  298000.000000  1987.000000  4.000000
# 3      50000.000000  147300.000000  197300.000000  1985.000000  3.000000
# 4      50000.000000  152300.000000  202300.000000  1984.000000  4.000000
# ...             ...            ...            ...          ...       ...
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day   Pin        Age     Rooms
# 0          3.000000      0.000000  2013      4    9  1808  36.000000  6.000000
# 1          3.000000      2.000000  2014      6   10  1832  24.000000  8.000000
# 2          3.000000      0.000000  2016      9   26  1864  35.000000  7.000000
# 3          3.000000      0.000000  2016      1   29  1853  37.000000  6.000000
# 4          3.000000      0.000000  2014     10   10  1829  38.000000  7.000000
# ...             ...           ...   ...    ...  ...   ...        ...       ...
# 56472      1.886014      0.283921  2015      5   27  1435  58.255101  5.259848
# 56473      1.886014      0.283921  2015      3    2  1423  58.255101  5.259848
# 56474      1.886014      0.283921  2016      8   16  1804  58.255101  5.259848
# 56475      1.886014      0.283921  2016      9    7  1709  58.255101  5.259848
# 56476      1.886014      0.283921  2016      9    7  1713  58.255101  5.259848
#
# [56477 rows x 19 columns]

# %%
np.corrcoef(data.Acre,data.SalePrice)
# Out:
# array([[1.       , 0.0550135],
#        [0.0550135, 1.       ]])

# %%
sns.regplot(x='Acre',y='SalePrice',data=data)

# %%
#The number of acre has very little influence in the SalePrice

# %% [markdown]
# 8. Are houses located in specific pin numbers expensive over the others?

# %%
data.tail(10)
# Out:
#        UniqueID                   LandUse  \
# 56467      52705  VACANT RESIDENTIAL LAND
# 56468      52706  VACANT RESIDENTIAL LAND
# 56469      52707  VACANT RESIDENTIAL LAND
# 56470      52708  VACANT RESIDENTIAL LAND
# 56471       9492            SINGLE FAMILY
# 56472      30469            SINGLE FAMILY
# 56473      27707            SINGLE FAMILY
# 56474      52709  VACANT RESIDENTIAL LAND
# 56475      54042  VACANT RESIDENTIAL LAND
# 56476      54043  VACANT RESIDENTIAL LAND
#
#                              PropertyAddress   SaleDate  SalePrice      Acre  \
# 56467  2221 VINEYARD GARDEN  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56468  2217 VINEYARD GARDEN  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56469  2213 VINEYARD GARDEN  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56470  2209 VINEYARD GARDEN  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56471    1437  WINDING CREEK DR, NOLENSVILLE 2013-11-08     168000  0.498923
# 56472    1435  WINDING CREEK DR, NOLENSVILLE 2015-05-27     157500  0.498923
# 56473    1423  WINDING CREEK DR, NOLENSVILLE 2015-03-02     145000  0.498923
# 56474      1804 GRACE POINT  LN, NOLENSVILLE 2016-08-16     234611  0.498923
# 56475     1709 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
# 56476     1713 PARK TERRACE  LN, NOLENSVILLE 2016-09-07      93844  0.498923
#
#           LandValue  BuildingValue     TotalValue    YearBuilt  Bedrooms  \
# 56467  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56468  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56469  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56470  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56471  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56472  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56473  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56474  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56475  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
# 56476  69068.557601  160784.677109  232375.398847  1963.744899  3.089912
#
#        FullBathroom  HalfBathroom  Year  Month  Day   Pin  Age     Rooms
# 56467      1.886014      0.283921  2016      8   16  2221  5.0  5.259848
# 56468      1.886014      0.283921  2016      8   16  2217  5.0  5.259848
# 56469      1.886014      0.283921  2016      8   16  2213  5.0  5.259848
# 56470      1.886014      0.283921  2016      8   16  2209  5.0  5.259848
# 56471      1.886014      0.283921  2013     11    8  1437  8.0  5.259848
# 56472      1.886014      0.283921  2015      5   27  1435  7.0  5.259848
# 56473      1.886014      0.283921  2015      3    2  1423  7.0  5.259848
# 56474      1.886014      0.283921  2016      8   16  1804  5.0  5.259848
# 56475      1.886014      0.283921  2016      9    7  1709  5.0  5.259848
# 56476      1.886014      0.283921  2016      9    7  1713  5.0  5.259848

# %%
data.dtypes
# Out:
# UniqueID                    int64
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# Acre                      float64
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBathroom              float64
# HalfBathroom              float64
# Year                        int64
# Month                       int64
# Day                         int64
# Pin                        object
# Age                       float64
# Rooms                     float64
# dtype: object

# %%
data['Pin'].astype(str)
data.dtypes
# Out:
# UniqueID                    int64
# LandUse                    object
# PropertyAddress            object
# SaleDate           datetime64[ns]
# SalePrice                   int64
# Acre                      float64
# LandValue                 float64
# BuildingValue             float64
# TotalValue                float64
# YearBuilt                 float64
# Bedrooms                  float64
# FullBathroom              float64
# HalfBathroom              float64
# Year                        int64
# Month                       int64
# Day                         int64
# Pin                        object
# Age                       float64
# Rooms                     float64
# dtype: object

# %%
g = data.groupby('Pin')['SalePrice']
g.count()
g.median()
# Out:
# Pin
#   12    195000.0
#   AC    450000.0
#   HA     19000.0
#   LO    287500.0
#   MA    591800.0
#           ...
# SUNN    398500.0
# TYNE    315000.0
# WASH    189900.0
# WEST    435000.0
# nan     169900.0
# Name: SalePrice, Length: 6531, dtype: float64

# %%
data.groupby('Pin')['Pin'].count()
# Out:
# Pin
#   12     1
#   AC     1
#   HA     1
#   LO     2
#   MA     1
#         ..
# SUNN     1
# TYNE     1
# WASH     2
# WEST     1
# nan     29
# Name: Pin, Length: 6531, dtype: int64

# %% [markdown]
# 9. How have house prices changed in the 21st centuary as supposed to 20th centuary.
